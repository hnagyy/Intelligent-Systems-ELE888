# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


def build_A_B_signed(seed=42):
    
    iris = load_iris()
    X = iris.data[:, [1, 2]]   # x1, x2
    y = iris.target            # class labels: 0,1,2

    A = X[y == 0]  # Setosa
    B = X[y == 1]  # Versicolour

    # Augment: y = [1, x1, x2]
    YA = np.hstack([np.ones((A.shape[0], 1)), A])   # (50,3)
    YB = np.hstack([np.ones((B.shape[0], 1)), B])   # (50,3)

    # Signed transform: class B samples are negated
    Y_all = np.vstack([YA, -YB])  # (100,3)

    # Shuffle
    rng = np.random.default_rng(seed)
    idx = rng.permutation(Y_all.shape[0])
    return Y_all[idx]
    
def build_B_C_signed(seed=42):

    iris = load_iris()
    X = iris.data[:, [1, 2]]   # x1, x2
    y = iris.target

    B = X[y == 1]  # Versicolour
    C = X[y == 2]  # Virginica

    YB = np.hstack([np.ones((B.shape[0], 1)), B])  # (50,3)
    YC = np.hstack([np.ones((C.shape[0], 1)), C])  # (50,3)

    
    Y_all= np.vstack([YB, -YC])  # (100,3)

    rng = np.random.default_rng(seed)
    idx = rng.permutation(Y_all.shape[0])
    return Y_all[idx]


def split_train_test(Y_all, train_frac=0.30):
    n = Y_all.shape[0]
    n_train = int(round(train_frac * n))
    Y_train = Y_all[:n_train]
    Y_test  = Y_all[n_train:]
    return Y_train, Y_test

def train_gd_perceptron(Y_train, eta=0.01, theta=0.0, a0=None, max_iter=300):
    if a0 is None:
        a = np.array([0.0, 0.0, 1.0], dtype=float)
    else:
        a = np.array(a0, dtype=float)

    history = []  # store (k, Jp, grad, a_copy, num_mis)

    for k in range(1, max_iter + 1):
        scores = Y_train @ a  #a^Tyi​
        mis = scores <= 0  # misclassified set Y(a)

        num_mis = int(np.sum(mis))
        if num_mis == 0:
            # exit if no misclassified
            break

        Ymis = Y_train[mis]

        grad = -np.sum(Ymis, axis=0)            # ∇Jp = Σ(-y)
        Jp = np.sum(-(Ymis @ a))                # Jp = Σ(-a^T y)

        history.append((k, float(Jp), grad.copy(), a.copy(), num_mis))

        # Update a value
        a = a - eta * grad

        # Optional stop rule from pseudo-code:
        if np.linalg.norm(eta * grad) < theta:
            break

    return a, history
    
def signed_to_xy_and_class(Y_signed):
    """
    Your signed samples look like:
      Class A:  [ 1,  x1,  x2]
      Class B:  [-1, -x1, -x2]
    So we can recover original (x1,x2) and class from the first entry.
    """
    y0 = Y_signed[:, 0]
    x1 = np.where(y0 > 0, Y_signed[:, 1], -Y_signed[:, 1])
    x2 = np.where(y0 > 0, Y_signed[:, 2], -Y_signed[:, 2])
    cls = np.where(y0 > 0, 0, 1)   # 0 = A, 1 = B
    return x1, x2, cls

def history_to_table(history):
    """
    history entries were stored as:
      (k, Jp, grad_vector, a_vector, num_mis)
    Task 5 wants: iteration, Jp(a), ∇Jp(a), a=[a0,a1,a2]
    :contentReference[oaicite:6]{index=6}
    """
    rows = []
    for (k, Jp, grad, a, num_mis) in history:
        rows.append({
            "k": k,
            "Jp(a)": Jp,
            "grad": grad,     # vector
            "a": a,           # vector
            "misclassified": num_mis
        })
    return pd.DataFrame(rows)

def plot_training_and_boundary(Y_train_signed, a, title=""):
    x1, x2, cls = signed_to_xy_and_class(Y_train_signed)

    # scatter training points
    plt.figure()
    plt.scatter(x1[cls == 0], x2[cls == 0], label="Class A")
    plt.scatter(x1[cls == 1], x2[cls == 1], label="Class B")

    # decision boundary: a0 + a1*x1 + a2*x2 = 0
    a0, a1, a2 = a
    x1_min, x1_max = x1.min(), x1.max()
    xs = np.linspace(x1_min, x1_max, 200)

    if abs(a2) < 1e-12:
        # vertical line if a2 ~ 0: a0 + a1*x1 = 0
        if abs(a1) > 1e-12:
            x_vert = -a0 / a1
            plt.axvline(x_vert, linestyle="--", label="Decision boundary")
    else:
        ys = -(a0 + a1 * xs) / a2
        plt.plot(xs, ys, linestyle="--", label="Decision boundary")

    plt.xlabel("x1 = sepal width")
    plt.ylabel("x2 = petal length")
    plt.title(title)
    plt.legend()
    plt.show()

def run_step5_AB():
    # Build A vs B and take a training set (you can use either 30% or 70% for Step 5)
    Y_all = build_A_B_signed(seed=7)
    Y_train, _ = split_train_test(Y_all, train_frac=0.70)  # choose 70% training for nicer plots

    etas = [0.01, 0.1]  # two different learning rates :contentReference[oaicite:7]{index=7}
    inits = [
        [0, 0, 1],
        [1, 1, 1],
        [-1, 0, 1],
    ]

    for eta in etas:
        for a0 in inits:
            a_final, hist = train_gd_perceptron(
                Y_train, eta=eta, theta=0.0, a0=a0, max_iter=300
            )

            # convergence iterations = last iteration in history, or 0 if already perfect
            iters = hist[-1][0] if len(hist) else 0

            print("\n==============================")
            print(f"eta = {eta}, a(0) = {a0}")
            print("final a =", a_final)
            print("iterations used =", iters)

            # 1) iteration table :contentReference[oaicite:8]{index=8}
            df = history_to_table(hist)
            print(df.head(10))  # show first 10 rows (you can print all if you want)

            # 2) training data + 3) decision boundary :contentReference[oaicite:9]{index=9}
            plot_training_and_boundary(
                Y_train, a_final,
                title=f"A vs B | eta={eta} | a0={a0} | iters={iters}"
            )

# Run Task 5 for A vs
# ==============================
# NEW: accuracy computation
# ==============================
def compute_accuracy(Y_test, a):
    """
    For signed samples:
      correctly classified if a^T y > 0
    """
    scores = Y_test @ a
    correct = scores > 0
    return np.mean(correct)


# ==============================
# NEW: run Tasks 1–4
# ==============================
def run_tasks_1_to_4():
    print("\n================ TASKS 1–4 =================")

    # ---- SETTINGS FROM QUESTION ----
    eta = 0.01
    theta = 0.0
    a_init = [0, 0, 1]
    max_iter = 300

    # helper to run one experiment
    def run_experiment(name, build_func, train_frac):
        print("\n--------------------------------")
        print(f"{name} | train={int(train_frac*100)}% "
              f"test={int((1-train_frac)*100)}%")

        # build dataset
        Y_all = build_func(seed=7)

        # split
        Y_train, Y_test = split_train_test(Y_all, train_frac=train_frac)

        # train
        a_final, hist = train_gd_perceptron(
            Y_train,
            eta=eta,
            theta=theta,
            a0=a_init,
            max_iter=max_iter
        )

        iters = hist[-1][0] if len(hist) else 0
        acc = compute_accuracy(Y_test, a_final)

        print("final a =", a_final)
        print("iterations =", iters)
        print(f"classification accuracy = {acc*100:.2f}%")

        # optional plot
        plot_training_and_boundary(
            Y_train,
            a_final,
            title=f"{name} | train={int(train_frac*100)}%"
        )

    # -------------------------------
    # TASK 1 + 2  (A vs B, 30/70)
    # -------------------------------
    run_experiment(
        "A vs B",
        build_A_B_signed,
        train_frac=0.30
    )

    # -------------------------------
    # TASK 3 (A vs B, 70/30)
    # -------------------------------
    run_experiment(
        "A vs B",
        build_A_B_signed,
        train_frac=0.70
    )

    # -------------------------------
    # TASK 4 (B vs C, both splits)
    # -------------------------------
    run_experiment(
        "B vs C",
        build_B_C_signed,
        train_frac=0.30
    )

    run_experiment(
        "B vs C",
        build_B_C_signed,
        train_frac=0.70
    )
# Run Tasks 1–4
run_tasks_1_to_4()

# Run Task 5
run_step5_AB()
# Out:
# ==============================
# eta = 0.01, a(0) = [0, 0, 1]
# final a = [ 0.26   1.605 -1.632]
# iterations used = 7
#    k     Jp(a)                                              grad  \
# 0  1  152.6000    [36.0, 100.50000000000001, 152.59999999999997]
# 1  2  156.1062              [-34.0, -117.4, -49.199999999999996]
# 2  3   11.0761    [36.0, 100.50000000000001, 152.59999999999997]
# 3  4  187.8184              [-34.0, -117.4, -49.199999999999996]
# 4  5   14.3636  [-32.0, -109.80000000000001, -46.99999999999999]
# 5  6   63.1432    [36.0, 100.50000000000001, 152.59999999999997]
# 6  7   56.6214              [-34.0, -117.4, -49.199999999999996]
#
#                                                    a  misclassified
# 0                                    [0.0, 0.0, 1.0]             36
# 1  [-0.36, -1.0050000000000001, -0.5259999999999998]             34
# 2  [-0.019999999999999962, 0.16900000000000004, -...             36
# 3  [-0.37999999999999995, -0.8360000000000001, -1...             34
# 4  [-0.039999999999999925, 0.3380000000000001, -1...             32
# 5  [0.2800000000000001, 1.4360000000000002, -0.59...             36
# 6  [-0.0799999999999999, 0.43100000000000005, -2....             34
# ==============================
# eta = 0.01, a(0) = [1, 1, 1]
# final a = [ 0.78   0.833 -1.834]
# iterations used = 6
#    k     Jp(a)                                               grad  \
# 0  1  289.1000     [36.0, 100.50000000000001, 152.59999999999997]
# 1  2    4.8022  [-33.0, -113.80000000000001, -48.199999999999996]
# 2  3  142.0721     [36.0, 100.50000000000001, 152.59999999999997]
# 3  4   41.4768               [-34.0, -117.4, -49.199999999999996]
# 4  5    6.3090                                 [20.0, 57.4, 81.1]
# 5  6    0.4955                                [-3.0, -10.5, -5.5]
#
#                                                    a  misclassified
# 0                                    [1.0, 1.0, 1.0]             36
# 1  [0.64, -0.0050000000000001155, -0.525999999999...             33
# 2                [0.97, 1.133, -0.04399999999999982]             36
# 3    [0.61, 0.1279999999999999, -1.5699999999999996]             34
# 4                 [0.95, 1.302, -1.0779999999999996]             20
# 5    [0.75, 0.7280000000000001, -1.8889999999999996]              3
# ==============================
# eta = 0.01, a(0) = [-1, 0, 1]
# final a = [-0.71   1.717 -1.6  ]
# iterations used = 7
#    k     Jp(a)                                            grad  \
# 0  1  116.6000   [35.0, 96.90000000000002, 151.59999999999997]
# 1  2  185.0478            [-34.0, -117.4, -49.199999999999996]
# 2  3   11.4538            [-34.0, -117.4, -49.199999999999996]
# 3  4  185.8863  [36.0, 100.50000000000001, 152.59999999999997]
# 4  5   43.1660            [-34.0, -117.4, -49.199999999999996]
# 5  6   44.3624  [36.0, 100.50000000000001, 152.59999999999997]
# 6  7   74.8782            [-34.0, -117.4, -49.199999999999996]
#
#                                                    a  misclassified
# 0                                   [-1.0, 0.0, 1.0]             37
# 1  [-1.35, -0.9690000000000002, -0.5159999999999998]             34
# 2  [-1.01, 0.20499999999999996, -0.0239999999999998]             34
# 3   [-0.6699999999999999, 1.379, 0.4680000000000002]             36
# 4  [-1.0299999999999998, 0.3739999999999999, -1.0...             34
# 5  [-0.6899999999999997, 1.548, -0.5659999999999996]             36
# 6  [-1.0499999999999998, 0.5429999999999999, -2.0...             34
# ==============================
# eta = 0.1, a(0) = [0, 0, 1]
# final a = [  3.    15.12 -14.76]
# iterations used = 5
#    k     Jp(a)                                            grad  \
# 0  1   152.600  [36.0, 100.50000000000001, 152.59999999999997]
# 1  2  2003.862            [-34.0, -117.4, -49.199999999999996]
# 2  3   267.922            [-34.0, -117.4, -49.199999999999996]
# 3  4   790.423  [36.0, 100.50000000000001, 152.59999999999997]
# 4  5   585.044            [-34.0, -117.4, -49.199999999999996]
#
#                                                    a  misclassified
# 0                                    [0.0, 0.0, 1.0]             36
# 1   [-3.6, -10.050000000000002, -14.259999999999998]             34
# 2  [-0.19999999999999973, 1.6899999999999995, -9....             34
# 3  [3.2000000000000006, 13.430000000000001, -4.41...             36
# 4  [-0.39999999999999947, 3.379999999999999, -19....             34
# ==============================
# eta = 0.1, a(0) = [1, 1, 1]
# final a = [  3.8   15.36 -14.98]
# iterations used = 5
#    k     Jp(a)                                              grad  \
# 0  1   289.100    [36.0, 100.50000000000001, 152.59999999999997]
# 1  2  1852.462              [-34.0, -117.4, -49.199999999999996]
# 2  3   118.018  [-32.0, -109.80000000000001, -46.99999999999999]
# 3  4   809.771    [36.0, 100.50000000000001, 152.59999999999997]
# 4  5   540.492              [-34.0, -117.4, -49.199999999999996]
#
#                                                    a  misclassified
# 0                                    [1.0, 1.0, 1.0]             36
# 1    [-2.6, -9.050000000000002, -14.259999999999998]             34
# 2  [0.8000000000000003, 2.6899999999999995, -9.33...             32
# 3      [4.0, 13.670000000000002, -4.639999999999999]             36
# 4     [0.3999999999999999, 3.619999999999999, -19.9]             34
# ==============================
# eta = 0.1, a(0) = [-1, 0, 1]
# final a = [  2.1   15.48 -14.66]
# iterations used = 5
#    k     Jp(a)                                            grad  \
# 0  1   116.600   [35.0, 96.90000000000002, 151.59999999999997]
# 1  2  1987.278            [-34.0, -117.4, -49.199999999999996]
# 2  3   251.338            [-34.0, -117.4, -49.199999999999996]
# 3  4   809.463  [36.0, 100.50000000000001, 152.59999999999997]
# 4  5   568.460            [-34.0, -117.4, -49.199999999999996]
#
#                                                    a  misclassified
# 0                                   [-1.0, 0.0, 1.0]             37
# 1    [-4.5, -9.690000000000003, -14.159999999999997]             34
# 2  [-1.0999999999999996, 2.049999999999999, -9.23...             34
# 3  [2.3000000000000007, 13.790000000000001, -4.31...             36
# 4  [-1.2999999999999994, 3.7399999999999984, -19....             34

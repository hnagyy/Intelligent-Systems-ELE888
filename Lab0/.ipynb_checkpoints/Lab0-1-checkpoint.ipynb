# %%
# import pandas library with alias pd ( library for data analysis )
import pandas as pd
# read csv and call it df ( data frame )
df = pd.read_csv ('http://bit.ly/autompg-csv ')
# print the first 5 rows of df
print (df.head () )
# scatter plot with horse power on x−axis and mile−per−gallon on y−axis
df . plot.scatter (x='hp', y= 'mpg')



# i m p o r t pandas l i b r a r y w i t h a l i a s pd ( l i b r a r y f o r d a t a a n a l y s i s )
import pandas as pd
# r ead c s v and c a l l i t d f ( d a t a frame )
df = pd.read_csv ( 'http://bit.ly/autompg-csv')
# p r i n t t h e f i r s t 5 rows o f d f
print(df.head())
# s c a t t e r p l o t w i t h h o r s e power on x−a x i s and mile −per−g a l l o n on y−a x i s
df.plot.scatter (x='hp', y= 'mpg')


import pandas as pd
import numpy as np
# d a t a frame w i t h 10 rows and 4 c o l s , random normal e l e m e n t s
# column l a b e l s A, B, C, and D
df = pd.DataFrame( np.random.randn(10,4),columns=list('ABCD'))
print (df)


import matplotlib.pyplot as plt
# p l o t column A v s t h e a r r a y 0 , 1 , 2 , . . . , 9
plt.plot(list(range(0,10)),df['A'])
plt.title('Data')
plt.xlabel('index')
plt.ylabel('value')
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70     US  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70     US          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70     US         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70     US              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70     US                ford torino
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 15
#      13 import pandas as pd
#      14 # r ead c s v and c a l l i t d f ( d a t a frame )
# ---> 15 df = pd.read_csv('example_data_file.csv')
#      16 # p r i n t t h e f i r s t 5 rows o f d f
#      17 print(df.head())
#
# ...
